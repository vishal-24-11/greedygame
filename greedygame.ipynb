# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import math

# %% [markdown]
# # Import dataset and Data Understanding

# %% [markdown]
# Let’s load the dataset in a pandas dataframe

# %%
data=pd.read_csv("sikka_data.csv")

# %% [markdown]
# # Splitting nov and dec data

# %%
nov_data=data.loc[31:]
oct_data=data.loc[:30]

# %% [markdown]
# # Correlation visualization b/w Referrals and other independent variables

# %% [markdown]
# **CORRELATION - DAU vs Referrals**

# %%
plt.figure(figsize=(10,5))
plt.scatter(oct_data['DAU'],oct_data['Referrals'])
plt.xlabel("DAU")
plt.xlabel("Referrals")
plt.title('DAV vs Referrals')
# Out:
# Text(0.5, 1.0, 'DAV vs Referrals')

# %% [markdown]
# **CORRELATION - Installs vs Referrals**

# %%
plt.figure(figsize=(10,5))
plt.scatter(oct_data['Installs'],oct_data['Referrals'])
plt.xlabel("Installs")
plt.xlabel("Referrals")
plt.title('Installs vs Referrals')
# Out:
# Text(0.5, 1.0, 'Installs vs Referrals')

# %% [markdown]
# **CORRELATION - Uninstalls vs Referrals**

# %%
plt.figure(figsize=(10,5))
plt.scatter(oct_data['Uninstalls'],oct_data['Referrals'])
plt.xlabel("Uninstalls")
plt.xlabel("Referrals")
plt.title('Uninstalls vs Referrals')
# Out:
# Text(0.5, 1.0, 'Uninstalls vs Referrals')

# %% [markdown]
# **CORRELATION - Signups vs Referrals**

# %%
plt.figure(figsize=(10,5))
plt.scatter(oct_data['Signups'],oct_data['Referrals'])
plt.xlabel("Signups")
plt.xlabel("Referrals")
plt.title('Signups vs Referrals')
# Out:
# Text(0.5, 1.0, 'Signups vs Referrals')

# %% [markdown]
# # Here we can see there is fairly linear relationship

# %% [markdown]
# # Independent and dependent Split for Train-test

# %%
#X is inependent variable and Y is dependent variable
X=oct_data.drop(['Date','Referrals',],axis=1)
y=oct_data.loc[:,'Referrals']

# %% [markdown]
# # Training the model using linear regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test=train_test_split(X,y,test_size=0.20, random_state=42)

# %% [markdown]
# **Linear regression function of sklearn is used to fit a linear regression model. The model is fitted using fit() function in
# which independent and dependent variable are passed as parameter.**

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **predict() function is used to predict for test for data. the input(independent feature data) is provided in this function
# and the model predict the values as per the training**

# %%
y_pred=reg.predict(X_test)

# %% [markdown]
# # Evaluate the model

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8756297446418773

# %% [markdown]
# # Visulize the predicted results

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
plt.xlabel("actual")
plt.xlabel("predicted")
plt.title('actual vs predicted')
# Out:
# Text(0.5, 1.0, 'actual vs predicted')

# %% [markdown]
# # Apply the Model in nov data to get the predicted value of referalls

# %%
nov_var=nov_data.drop(['Date','Referrals',],axis=1)

# %%
nov_ref_pred=reg.predict(nov_var)

# %%
nov_ref_pred
# Out:
# array([500.50016678, 448.03164094, 411.01018518, 463.88856001,
#        447.9178645 , 471.06340866, 444.61931032, 501.45880514,
#        540.75841479, 542.13782028, 556.47032113, 551.85433103,
#        571.81749742, 564.46952967, 708.52308602])
